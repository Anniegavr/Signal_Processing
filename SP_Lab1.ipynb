# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
t = np.linspace(0, 1, 500, endpoint=False)
plt.plot(t, signal.square(2 * np.pi * 5 * t))
plt.ylim(-2, 2)
# plt.show()
# Out:
# (-2.0, 2.0)

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
w0 = 10 * np.pi
rho = 0.5
t = np.linspace(0, 1, 100, endpoint=False)
plt.plot(t, signal.square(w0 * t+rho))
plt.plot(t, signal.square((w0+1) * t+0.5))
plt.title("Ex. 1.1 Semnal periodic in forma dreptunghiulara")
plt.xlabel("t, sec")
plt.ylabel("X(t)")
plt.ylim(-5, 5)
plt.grid()
O = "Original impulse"
M = "Modified impulse"
plt.legend([O,M])
# plt.show()

# %%
from numpy import fft
def rect(t,tau):
    """
    Approximation to the rectangle pulse Pi(t/tau).
    
    In this numerical version of Pi(t/tau) the pulse is active
    over -tau/2 <= t <= tau/2.
    
    Parameters
    ----------
    t : ndarray of the time axis
    tau : the pulse width
    
    Returns
    -------
    x : ndarray of the signal Pi(t/tau)
    
    Examples
    --------
    >>> import matplotlib.pyplot as plt
    >>> from numpy import arange
    >>> from sk_dsp_comm.sigsys import rect
    >>> t = arange(-1,5,.01)
    >>> x = rect(t,1.0)
    >>> plt.plot(t,x)
    >>> plt.ylim([0, 1.01])
    >>> plt.show()

    To turn on the pulse at t = 1 shift t.

    >>> x = rect(t - 1.0,1.0)
    >>> plt.plot(t,x)
    >>> plt.ylim([0, 1.01])
    """
    x = np.zeros(len(t))
    for k,tk in enumerate(t):
        if np.abs(tk) > tau/2.:
            x[k] = 0
        else:
            x[k] = 1
    return x
def tri(t,tau):
    """
    Approximation to the triangle pulse Lambda(t/tau).
    
    In this numerical version of Lambda(t/tau) the pulse is active
    over -tau <= t <= tau.
    
    Parameters
    ----------
    t : ndarray of the time axis
    tau : one half the triangle base width
    
    Returns
    -------
    x : ndarray of the signal Lambda(t/tau)
    
    Examples
    --------
    >>> import matplotlib.pyplot as plt
    >>> from numpy import arange
    >>> from sk_dsp_comm.sigsys import tri
    >>> t = arange(-1,5,.01)
    >>> x = tri(t,1.0)
    >>> plt.plot(t,x)
    >>> plt.show()

    To turn on at t = 1, shift t.

    >>> x = tri(t - 1.0,1.0)
    >>> plt.plot(t,x)
    """
    x = np.zeros(len(t))
    for k,tk in enumerate(t):
        if np.abs(tk) > tau/1.:
            x[k] = 0
        else:
            x[k] = 1 - np.abs(tk)/tau
    return x

# %%
t = np.linspace(-4, 10, 100, endpoint=False)
x_rect = rect(t-3,2)
x_modified_rect = rect(t-6, 2)
plt.xlabel("t, sec")
plt.plot(t,x_rect)
plt.plot(t, x_modified_rect)
plt.grid()
plt.legend(["Original pulse", "Modified pulse"])
plt.title("Rectangular pulse")
# plt.show()
# Out:
# Text(0.5, 1.0, 'Rectangular pulse')

# %%
x_tri = tri(t+2,1.5)  #tri - implemented above
x_modified_tri = tri(t-2, 1.5)
t = np.linspace(-4, 9, 100, endpoint=False)
plt.plot(t,x_tri)
plt.plot(t, x_modified_tri)
plt.grid()
plt.legend(["Original pulse", "Modified pulse"])
plt.title("Tripuls")
plt.xlabel("t, sec")
# plt.show()
# Out:
# Text(0.5, 0, 't, sec')

# %%
t = np.linspace(0, 3, 100, endpoint=False)
plt.plot(t, signal.sawtooth(2 * np.pi * 5 * t))
plt.plot(t, signal.sawtooth(0.5 * np.pi * 5 * t))
plt.xlim(0, 3)
plt.grid()
plt.xlabel("t, sec")
plt.ylabel("X(t)")
plt.legend(["Original pulse", "Modified pulse"])
# plt.show()

# %%
x = np.linspace(0,4*np.pi,500)   # start,stop,step
x_modif = np.linspace(1,2*np.pi, 500)
y = np.cos(x)
y_modif = np.cos(x_modif)
plt.plot(x,y)
plt.plot(x_modif,y_modif)
plt.grid()
plt.xlabel("x values from 0 to 4pi")
plt.ylabel("cos(x)")
plt.title("Plot of cos from 0 to 4pi")
plt.legend(["cos(x)", "cos1(x_modif)"])
# plt.show()

# %%
x = np.arange(0,4*np.pi,0.05)   # start,stop,step
x_modif = np.arange(1,2*np.pi, 0.05)
y = np.cos(x)
y_modif = np.cos(x_modif)
plt.plot(x,y)
plt.plot(x_modif,y_modif)
plt.grid()
plt.xlabel('x values from 0 to 4pi')
plt.ylabel('cos(x)')
plt.title('Plot of cos from 0 to 4pi')
plt.legend(['cos(x)', 'cos1(x_modif)'])
# plt.show()

# %%
x = np.arange(0,4*np.pi,0.005)   # start,stop,step
x_modif = np.arange(1,2*np.pi, 0.05)
y = np.cos(x)
y_modif = np.cos(x_modif)
plt.xlim(0,14)
plt.stem(x, y, use_line_collection=True)
plt.grid()
plt.xlabel('x values from 0 to 4pi')
plt.ylabel('cos(x)')
plt.title('Plot of cos from 0 to 4pi')
plt.legend("cos(x)")

# %%
x = np.arange(4.7,6*np.pi,0.25)   # start,stop,step
x_modif = np.arange(1,2*np.pi, 0.05)
y = np.cos(x)
y_modif = np.cos(x_modif)
plt.xlim(4,14)
plt.stem(x, y, use_line_collection=True)
plt.grid()
plt.xlabel('x values from 0 to 4pi')
plt.ylabel('cos(x)')
plt.title('Plot of modified step cos from 0 to 4pi - step=0.35')
plt.legend("cos(x)")

# %%
x = np.arange(0,4*np.pi,0.15)   # start,stop,step
x_modif = np.arange(1,2*np.pi, 0.05)
y = np.cos(x)
y_modif = np.cos(x_modif)
plt.xlim(0,14)
plt.bar(x, y)
plt.grid()
plt.xlabel('x values from 0 to 4pi')
plt.ylabel('cos(x)')
plt.title('Bar plot of cos from 0 to 4pi')
plt.legend('cos(x)')
# plt.show()

# %%
x = np.arange(0,4*np.pi,0.45)   # start,stop,step
y = np.cos(x)
y_modif = np.cos(x_modif)
plt.xlim(0,14)
plt.grid()
plt.bar(x, y)
plt.xlabel('x values from 0 to 4pi')
plt.ylabel('cos(x)')
plt.title('Modified bar plot of cos from 0 to 4pi')
plt.legend('cos(x)')

# %%
t = np.arange(0, 5, 0.05) # start,stop,step
a = 5
y = np.exp(a*t)
plt.xlim(0,6)
plt.plot(t, y)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('A*exp(a*t)')
plt.title('Exp plot of a=5')
# Out:
# Text(0.5, 1.0, 'Exp plot of a=5')

# %%
t = np.linspace(0, 70, 100, endpoint=False)
a=5
a1=4.5
a2=3
y=np.exp(a*t)
y1=np.exp(5*t)
y2=np.exp(a2*t)
# plt.xlim(0,7)
plt.plot(t, y)
# plt.plot(t,y1)
plt.plot(t, y2)
plt.grid()
plt.xlabel('t values from 0 to 5')
plt.ylabel('exp(a*t)')
plt.legend(["exp", "exp1", "exp2"])
plt.title('Exp plot of a=16')
# Out:
# Text(0.5, 1.0, 'Exp plot of a=16')

# %%
t = np.arange(0, 9, 0.05) # start,stop,step
a=-5
y = np.exp(a*t)
plt.xlim(0,8.9)
plt.plot(t, y)
plt.grid()
plt.xlabel('t values from 0 to 9')
plt.ylabel('exp(a*t)')
plt.title('Exp plot of a=-5')
# Out:
# Text(0.5, 1.0, 'Exp plot of a=-5')

# %%
t = np.arange(0, 9, 0.05) # start,stop,step
a=-5
a1=-16
y = np.exp(a*t)
y1=np.exp(a1*t)
plt.xlim(0,8.9)
plt.plot(t, y, t, y1)
plt.grid()
plt.xlabel('t values from 0 to 9')
plt.ylabel('exp(a*t)')
plt.legend(["exp", "exp1"])
plt.title('Exp plot of a=-5')
# Out:
# Text(0.5, 1.0, 'Exp plot of a=-5')

# %%
n = np.arange(-10, 10, 0.5) # start,stop,step
B=5
r=0.85
pwr=B*r**n
plt.stem(n,pwr, use_line_collection=True)
plt.grid()
plt.xlabel('n values from -10 to 10')
plt.ylabel('pwr=B*r.^n')
plt.title('Power function plot')
# Out:
# Text(0.5, 1.0, 'Power function plot')

# %%
n = np.arange(-10, 10, 0.5) # start,stop,step
B=5
B1=30
r=0.85
pwr=B*r**n
pwr1=B1*r**n
plt.stem(n,pwr, use_line_collection=True)
plt.stem(n,pwr1, use_line_collection=True)
plt.grid()
plt.xlabel('n values from -10 to 10')
plt.ylabel('pwr=B*r.^n')
plt.legend(["pwr", "pwr1"])
plt.title('Power function plot')
# Out:
# Text(0.5, 1.0, 'Power function plot')

# %%
t = np.arange(0,1,0.001) # start,stop,step
A=60
phi=0
a=6
w0=20*np.pi;
expsin=A*np.sin(w0*t+phi)*np.exp((-a)*t);
y = expsin
# plt.xlim(0,12)
plt.plot(t, y)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('expsin')
plt.title('Descending plot: sin and exp')
# Out:
# Text(0.5, 1.0, 'Descending plot: sin and exp')

# %%
t = np.arange(0,1,0.001) # start,stop,step
A=60
phi=0
a=6
w0=20*np.pi;
expsin=A*np.sin(w0*t+phi)*np.exp((-a)*t);
A1=60
phi1=0
a1=0.1
w01=20*np.pi;
expsin1=A1*np.sin(w01*t+phi1)*np.exp((-a1)*t);
# plt.xlim(0,12)
plt.plot(t, expsin, t, expsin1)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('expsin')
plt.legend(["expsin","expsin1"])
plt.title('Descending plot: sin and exp')
# Out:
# Text(0.5, 1.0, 'Descending plot: sin and exp')

# %%
t = np.arange(-10,10,0.001) # start,stop,step
k=3
w=1
s=0.5
A=2
gp=A*signal.gausspulse(t+k,w,s)
y = gp
# plt.xlim(0,12)
plt.plot(t, y)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('gp')
plt.title('Gaus pulse plot')
# Out:
# Text(0.5, 1.0, 'Gaus pulse plot')

# %%
t = np.arange(-10,10,0.001) # start,stop,step
k=3
w=1
s=0.5
A=2
k1=7
w1=0.7
s1=0.5
A1=2
gp=A*signal.gausspulse(t+k,w,s)
gp1=A1*signal.gausspulse(t+k1,w1,s1)
plt.plot(t, gp, t, gp1)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('gp')
plt.title('Gaus pulse plot')
# Out:
# Text(0.5, 1.0, 'Gaus pulse plot')

# %%
t = np.arange(0,50,0.01) # start,stop,step
ft=0.7*np.sinc(np.pi*(t-25)/5)
plt.plot(t, ft)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('ft')
plt.title('Fourier transformation plot')
# Out:
# Text(0.5, 1.0, 'Fourier transformation plot')

# %%
t = np.arange(0,50,0.01) # start,stop,step
ft=0.7*np.sinc(np.pi*(t-25)/5)
ft1=0.9*np.sinc(np.pi*(t-20)/5)
plt.plot(t, ft, t, ft1)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('ft2')
plt.legend(["ft","ft1"])
plt.title('Fourier transformation plot')
# Out:
# Text(0.5, 1.0, 'Fourier transformation plot')

# %%
t = np.linspace(0, 10, 1500) # start,stop,step
cp=signal.chirp(t, f0=6, f1=1, t1=10, method='linear')
# cp=0.75*signal.chirp(t)
plt.plot(t, cp)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('cp')
plt.title('Chirp plot')
# Out:
# Text(0.5, 1.0, 'Chirp plot')

# %%
t = np.linspace(0, 10, 1500) # start,stop,step
cp=signal.chirp(t, f0=6, f1=1, t1=10, method='linear')
cp1=signal.chirp(t, f0=0.9, f1=6, t1=10, method='linear')
# cp=0.75*signal.chirp(t)
plt.plot(t, cp, t, cp1)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('cp')
plt.legend(["cp", "cp1"])
plt.title('Chirp plot')
# Out:
# Text(0.5, 1.0, 'Chirp plot')

# %%
from scipy import special
t = np.arange(1, 50, 0.01) # start,stop,step
diric=0.7*special.diric(t,4)
diric1=0.9*special.diric(t,9)

plt.plot(t,diric)
plt.plot(t,diric1)
plt.grid()
plt.xlabel('t, sec')
plt.ylabel('diric, diric1')
plt.title('Dirichlet plot')
plt.legend(["Dir","Dir1"])
